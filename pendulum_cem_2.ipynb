# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/sampling_based_general/blob/main/pendulum_cem_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alinjar1996/sampling_based_general.git -b issue_2_pendulum
# Out:
# Cloning into 'sampling_based_general'...
# remote: Enumerating objects: 3822, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 3822 (delta 32), reused 41 (delta 19), pack-reused 3759 (from 2)
# Receiving objects: 100% (3822/3822), 572.87 MiB | 26.17 MiB/s, done.
# Resolving deltas: 100% (1882/1882), done.
# Updating files: 100% (791/791), done.

# %%
# %cd /content/sampling_based_general
# !git pull
# Out:
# /content/sampling_based_general
# Already up to date.

# %%
# !pip install --upgrade pip

# !grep -v -E "nvidia-" requirements.txt | \
pip install --timeout 1000 --no-cache-dir -r /dev/stdin
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 112.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 220.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 311.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.3/604.3 kB 635.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 655.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 MB 220.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 MB 146.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 174.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 245.5 MB/s  0:00:00
# ...

# %%
# %cd /content/sampling_based_general/real_demo/math_utils/

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git
# Out:
# /content/sampling_based_general/real_demo/math_utils
# Cloning into 'math_utils_aks_lab'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 117 (delta 59), reused 101 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 12.73 MiB | 27.11 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !rm -rf math_utils
# %cd /content/sampling_based_general/real_demo
# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils
# Out:
# /content/sampling_based_general/real_demo
# Cloning into 'math_utils'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 117 (delta 59), reused 101 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 12.73 MiB | 32.51 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !pip install jaxopt lineax
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 33.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 MB 37.5 MB/s  0:00:02
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.5.3
#     Uninstalling jaxlib-0.5.3:
#       Successfully uninstalled jaxlib-0.5.3
#   Attempting uninstall: jax
#     Found existing installation: jax 0.5.3
#     Uninstalling jax-0.5.3:
#       Successfully uninstalled jax-0.5.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [lineax]
# ...

# %%
import os
os.environ["MUJOCO_GL"] = "egl"

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:9 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# ...

# %%
# !python3 real_demo/pendulum_demo_pyt_colab.py
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jaxlib/plugin_support.py:91: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.5.3 is installed, but it is not compatible with the installed jaxlib version 0.9.1, so it will not be used.
#   warnings.warn(
# Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/jax/_src/xla_bridge.py", line 497, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/usr/local/lib/python3.12/dist-packages/jax_plugins/xla_cuda12/__init__.py", line 97, in initialize
#     xla_client.register_custom_type_id_handler(
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jaxlib.xla_client' has no attribute 'register_custom_type_id_handler'. Did you mean: 'register_custom_type_handler'?
# \Torque-controlled joints:
#   0: 'pendulum_joint' -> controlled: True
#
#  Default backend: cpu
#  Timestep: 0.1
# ...

# %%
from IPython.display import Video
Video("pendulum_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
! git add .
# !git config --global user.email alinjardannitdgp2014@gmail.com
# !git config --global user.name alinjar1996
# !git commit -m "colab comaptible code updated for video viewing. issue #2"
# Out:
# [issue_2_pendulum 27baa86] colab comaptible code updated for video viewing. issue #2
#  6 files changed, 62 insertions(+), 48 deletions(-)
#  create mode 100644 pendulum_sim.gif
#  create mode 100644 pendulum_sim.mp4
#  create mode 100644 pendulum_video.mp4

# %%
# !git push origin issue_2_pendulum
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
